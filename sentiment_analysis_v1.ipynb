# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize import sent_tokenize

# %%
# Only required on the first run
nltk.download('vader_lexicon')
nltk.download('punkt', force=True)
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Instantiate our analyzer
sid = SentimentIntensityAnalyzer()

# %%
# Load VADER lexicon
vader_lexicon = SentimentIntensityAnalyzer().lexicon

# %%
from google.colab import drive
drive.mount('/content/drive')

df = pd.read_csv('/content/drive/My Drive/cleaned_womens_orgs_WI_FB.csv')
# Out:
# Mounted at /content/drive

# %%
df.head()
# Out:
#                   date    type  \
# 0  2010-01-06 18:04:43    link
# 1  2010-01-04 20:59:14  status
# 2  2010-01-04 20:54:57  status
# 3  2010-01-04 19:27:43    link
# 4  2009-12-23 19:26:50    link
#
#                                                title  \
# 0  Rates among teenagers of sexually transmitted ...
# 1                                                NaN
# 2                                                NaN
# 3  Meta House, Inc. receives grant from the Women...
# 4  Give the Gift of Social Change this Holiday Se...
#
#                       caption  \
# 0            host.madison.com
# 1                         NaN
# 2                         NaN
# 3  milwaukeecourieronline.com
# 4              womensfund.com
#
#                                          description  \
# 0                              madison.com home page
# 1                                                NaN
# 2                                                NaN
# 3  Meta House received a $10,000 grant from the W...
# 4  The Women's Fund of Greater Milwaukee is a soc...
#
#                                              message  \
# 0          Good work by PPWI, a member organization!
# 1  WWN presents the 2010 Board who will continue ...
# 2  As we welcome 2010, the Wisconsin Women's Netw...
# 3                                                NaN
# 4  Give the Gift of Social Change this Holiday Se...
#
#    statistics.actual.likeCount  statistics.actual.shareCount  \
# 0                            0                             0
# 1                            0                             0
# 2                            0                             0
# 3                            1                             0
# 4                            1                             0
#
#    statistics.actual.commentCount                       account.name  \
# 0                               0          Wisconsin Women's Network
# 1                               0          Wisconsin Women's Network
# 2                               0          Wisconsin Women's Network
# 3                               0  Women's Fund of Greater Milwaukee
# 4                               1  Women's Fund of Greater Milwaukee
#
#     account.handle  account.subscriberCount  \
# 0  wiwomensnetwork                     4867
# 1  wiwomensnetwork                     4867
# 2  wiwomensnetwork                     4867
# 3    womensfundmke                     2162
# 4    womensfundmke                     2162
#
#                              account.pageDescription account.pageCreatedDate  \
# 0  An organization that promotes the advancement ...               education
# 1  An organization that promotes the advancement ...               education
# 2  An organization that promotes the advancement ...               education
# 3  Our mission is to mobilize philanthropy and fo...     2009-04-24 16:46:47
# 4  Our mission is to mobilize philanthropy and fo...     2009-04-24 16:46:47
#
#    account.pageCategory  account.verified  \
# 0              advocacy  and connections.
# 1              advocacy  and connections.
# 2              advocacy  and connections.
# 3  CHARITY_ORGANIZATION             FALSE
# 4  CHARITY_ORGANIZATION             FALSE
#
#                                                media  time_posted  \
# 0                                                und        18.04
# 1                                                und        20.59
# 2                                                und        20.54
# 3                                                NaN        19.27
# 4  photo, https://external-sea1-1.xx.fbcdn.net/em...        19.26
#
#            acc_category
# 0              advocacy
# 1              advocacy
# 2              advocacy
# 3  CHARITY_ORGANIZATION
# 4  CHARITY_ORGANIZATION

# %%
df['message'] = df['message'].astype(str)

# %%
df['message_score'] = df['message'].apply(
    lambda x: sid.polarity_scores(x).get('compound', 0))

# %%
df[['account.name','message','message_score']].sample(5)
# Out:
#                                         account.name  \
# 24191                Wisconsin Women in Conservation
# 9436   Madison NOW - National Organization for Women
# 12511      The Foundation for Black Women's Wellness
# 21097                                TEMPO Milwaukee
# 17315      The Foundation for Black Women's Wellness
#
#                                                  message  message_score
# 24191                                                nan         0.0000
# 9436   Thanks to everyone who came out to expose Acce...        -0.4588
# 12511  Thanks this morning to Kathi Seiden-Thomas and...         0.9466
# 21097  TEMPO had a blast at last night’s @pearls_mke ...         0.6219
# 17315  Friends! Join us next week, Wed, Dec. 15th for...         0.9685

# %%
df.to_csv('/content/drive/My Drive/sentiment_women_v1.csv', index=False)
